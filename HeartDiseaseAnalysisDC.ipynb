# %% [markdown]
# ## Health Indicator - Heart Disease

# %% [markdown]
# #### Import Libraries

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the heart_2020 dataset
heart_df = pd.read_csv('data/heart_2020_cleaned.csv')

# %%
heart_df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
# review the data available
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
heart_df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
# check for null values
heart_df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
# generate HTML table from the dataframe containing the initial dataset

# heart_df_table=(heart_df.to_html())
# heart_df.to_html('output/heart_df_table.html')

# %%
# read the WHOMortalityDatabase_Map_Cardiovascular_diseases_130422_22_05 dataset
who_df = pd.read_csv('data/WHOMortalityDatabase_Map_Cardiovascular_diseases_130422_22_05.csv')

# %%
who_df.head()
# Out:
#   Region Code Region Name Country Code Country Name  Year  Sex Age group code  \
# 0          EU      Europe          ALB      Albania  1987  All        Age_all
# 1          EU      Europe          ALB      Albania  1987  All          Age00
# 2          EU      Europe          ALB      Albania  1987  All       Age01_04
# 3          EU      Europe          ALB      Albania  1987  All       Age05_09
# 4          EU      Europe          ALB      Albania  1987  All       Age10_14
#
#   Age Group  Number  Percentage of cause-specific deaths out of total deaths  \
# 0     [All]  6388.0                                          36.869445
# 1       [0]     5.0                                           0.203335
# 2     [1-4]    39.0                                           3.157895
# 3     [5-9]     6.0                                           2.970297
# 4   [10-14]     6.0                                           4.444444
#
# ...

# %%
# check for null values
who_df.isnull().sum()
# Out:
# Region Code                                                         0
# Region Name                                                         0
# Country Code                                                        0
# Country Name                                                        0
# Year                                                                0
# Sex                                                                 0
# Age group code                                                      0
# Age Group                                                           0
# Number                                                           1593
# Percentage of cause-specific deaths out of total deaths          9763
# Age-standardized death rate per 100 000 standard population    283341
# Death rate per 100 000 population                               25020
# dtype: int64
